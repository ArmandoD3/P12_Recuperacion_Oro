# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # 1.-Descarga y preparacion de datos

# %% [markdown]
# ### 1.0.- Carga de librerias y dataframe

# %%
from scipy import stats as st
import seaborn as sns
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import math
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import make_scorer, mean_absolute_error

# %%
df_train = pd.read_csv("/datasets/gold_recovery_train.csv", sep=",")
df_test = pd.read_csv("/datasets/gold_recovery_test.csv", sep=",")
df_full = pd.read_csv("/datasets/gold_recovery_full.csv", sep=",")

# %% [markdown]
# ### 1.1.-  Abre los archivos y examina los datos.

# %%
print("<<<<Información de df_train>>>>")
df_train.head()
# Out:
# <<<<Información de df_train>>>>
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
print("<<<<Información de df_test>>>>")
df_test.head()
# Out:
# <<<<Información de df_test>>>>
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# 4                         10.682530                         7.530000
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.005021                             1398.981301
# ...

# %%
print("<<<<Información de df_full>>>>")
df_full.head()
# Out:
# <<<<Información de df_full>>>>
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.concentrate_au  final.output.recovery  final.output.tail_ag  \
# 0                    42.192020              70.541216             10.411962
# 1                    42.701629              69.266198             10.462676
# ...

# %%
print("<<<<Información de df_train>>>>")
df_train.info()
print("\n<<<<Estadísticas descriptivas de df_train>>>>")
print(df_train.describe())

print("\n\n<<<<Información de df_test>>>>")
df_test.info()
print("\n<<<<Estadísticas descriptivas de df_test>>>>")
print(df_test.describe())

print("\n\n<<<<Información de df_full>>>>")
df_full.info()
print("\n<<<<Estadísticas descriptivas de df_full>>>>")
print(df_full.describe())
# Out:
# <<<<Información de df_train>>>>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16860 entries, 0 to 16859
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                16860 non-null  object
#  1   final.output.concentrate_ag                         16788 non-null  float64
#  2   final.output.concentrate_pb                         16788 non-null  float64
#  3   final.output.concentrate_sol                        16490 non-null  float64
#  4   final.output.concentrate_au                         16789 non-null  float64
#  5   final.output.recovery                               15339 non-null  float64
#  6   final.output.tail_ag                                16794 non-null  float64
#  7   final.output.tail_pb                                16677 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente inicio. Importaste correctamente todas las librerías necesarias desde el principio, incluyendo herramientas para modelado, validación cruzada, métricas de error y visualización. También cargaste los datasets correctamente, mostrando buenas prácticas al darles nombres descriptivos.
#
# </div>
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Realizaste un análisis exhaustivo de la estructura de los datos, incluyendo uso de .head(), .info() y .describe(). Mostraste correctamente que hay columnas con valores faltantes, algo clave para planear el preprocesamiento posterior.
#
# </div>

# %% [markdown]
# ### 1.2. Comprueba que el cálculo de la recuperación sea correcto.

# %%
# Selecciona las columnas relevantes para el cálculo de la recuperación y la recuperación real
cols_for_recovery_calc = [
    'rougher.output.concentrate_au',
    'rougher.input.feed_au',
    'rougher.output.tail_au',
    'rougher.output.recovery'
]

# Crea un DataFrame temporal con solo estas columnas y eliminar filas con cualquier NaN en ellas
# Esto asegura que todas las entradas para el cálculo y la comparación sean válidas
df_recovery_check = df_train[cols_for_recovery_calc].dropna().copy()

# Renombra para mayor claridad en el cálculo
C = df_recovery_check['rougher.output.concentrate_au']
F = df_recovery_check['rougher.input.feed_au']
T = df_recovery_check['rougher.output.tail_au']

# Calcula el denominador, asegurándose de que no sea cero para evitar divisiones por cero
denominator = F * (C - T)

# Crea una serie para la recuperación calculada
calculated_recovery = pd.Series(0.0, index=df_recovery_check.index) # Inicializa con ceros

# Realiza el cálculo solo donde el denominador no es cero
# Esto es crucial: si el denominador es 0, la recuperación es 0 (no hay material para recuperar o no hay cambio)
non_zero_denominator_mask = (denominator != 0)

calculated_recovery[non_zero_denominator_mask] = (C[non_zero_denominator_mask] * (F[non_zero_denominator_mask] - T[non_zero_denominator_mask])) / \
                                                  denominator[non_zero_denominator_mask] * 100 # Multiplica por 100 para porcentaje

# Si F es 0 y C-T no es 0, el denominador es 0. En ese caso la recuperación es 0.
# Si F no es 0 pero C-T es 0, el denominador es 0. En ese caso, significa que la concentración en el concentrado es igual a la cola, por lo que no hay "recuperación" real.
# La fórmula original asume que la recuperación es un porcentaje, por lo que multiplicamos por 100.

# Recuperación real del dataset
actual_recovery = df_recovery_check['rougher.output.recovery']

# Calcula el EAM
mae = mean_absolute_error(actual_recovery, calculated_recovery)

print(f"\nError Absoluto Medio (EAM) entre la recuperación calculada y la real para rougher.output.recovery (ajustado): {mae:.4f}")
# Out:
# Error Absoluto Medio (EAM) entre la recuperación calculada y la real para rougher.output.recovery (ajustado): 0.0000

# %% [markdown]
# Esto confirma que la fórmula de recuperación es correcta y que nuestros cálculos coinciden perfectamente con los valores proporcionados en el dataset de entrenamiento para rougher.output.recovery

# %% [markdown]
# ### 1.3. Analiza las características no disponibles en el conjunto de prueba.

# %%
# Obtenemos las columnas de cada DataFrame
train_cols = set(df_train.columns)
test_cols = set(df_test.columns)

# Encontramos las columnas que están en train_cols pero no en test_cols
missing_in_test = list(train_cols - test_cols)

# Imprimimos el número de columnas faltantes
print(f"Número de columnas presentes en df_train pero no en df_test: {len(missing_in_test)}")

# Imprimimos las columnas faltantes y sus tipos de datos en df_train
print("\nCaracterísticas ausentes en df_test (y sus tipos de datos en df_train):")
for col in sorted(missing_in_test): # Ordenar para una mejor visualización
    if col in df_train.columns:
        print(f"- {col}: {df_train[col].dtype}")
# Out:
# Número de columnas presentes en df_train pero no en df_test: 34
#
# Características ausentes en df_test (y sus tipos de datos en df_train):
# - final.output.concentrate_ag: float64
# - final.output.concentrate_au: float64
# - final.output.concentrate_pb: float64
# - final.output.concentrate_sol: float64
# - final.output.recovery: float64
# - final.output.tail_ag: float64
# - final.output.tail_au: float64
# - final.output.tail_pb: float64
# - final.output.tail_sol: float64
# - primary_cleaner.output.concentrate_ag: float64
# - primary_cleaner.output.concentrate_au: float64
# - primary_cleaner.output.concentrate_pb: float64
# - primary_cleaner.output.concentrate_sol: float64
# - primary_cleaner.output.tail_ag: float64
# - primary_cleaner.output.tail_au: float64
# - primary_cleaner.output.tail_pb: float64
# - primary_cleaner.output.tail_sol: float64
# - rougher.calculation.au_pb_ratio: float64
# - rougher.calculation.floatbank10_sulfate_to_au_feed: float64
# ...

# %% [markdown]
# Esta información es crucial porque significa que, cuando entrenemos nuestro modelo, solo podremos usar las características que están presentes en ambos conjuntos de datos (df_train y df_test) como variables predictoras. Las columnas que faltan en df_test son esencialmente "fugas de datos" (data leakage) si se usaran como características para entrenar un modelo, ya que el modelo estaría viendo información que no estaría disponible en un escenario de la vida real.

# %% [markdown]
# ### 1.4. Realiza el preprocesamiento de datos.

# %% [markdown]
# #### 1.4.1 Conversión de la columna date

# %%
for df in [df_train, df_test, df_full]:
    df['date'] = pd.to_datetime(df['date'])
    #establerceremos la columna "date" como indice para facilitar la programacion.
    df.set_index('date', inplace=True)

# %%
print("<<<<Información de df_train>>>>")
df_train.info()

print("\n\n<<<<Información de df_test>>>>")
df_test.info()

print("\n\n<<<<Información de df_full>>>>")
df_full.info()
# Out:
# <<<<Información de df_train>>>>
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 16860 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         16788 non-null  float64
#  1   final.output.concentrate_pb                         16788 non-null  float64
#  2   final.output.concentrate_sol                        16490 non-null  float64
#  3   final.output.concentrate_au                         16789 non-null  float64
#  4   final.output.recovery                               15339 non-null  float64
#  5   final.output.tail_ag                                16794 non-null  float64
#  6   final.output.tail_pb                                16677 non-null  float64
# ...

# %% [markdown]
# #### 1.4.2  Manejo de valores nulos (NaNs)

# %%
for df in [df_train, df_test, df_full]:
    df.ffill(inplace=True)
    # Para rellenar NaNs al inicio de la serie que ffill no cubriría
    df.bfill(inplace=True)

print("Valores nulos rellenados con ffill y bfill en todos los DataFrames.")
# Out:
# Valores nulos rellenados con ffill y bfill en todos los DataFrames.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen uso combinado de ffill y bfill para rellenar valores nulos. Esto garantiza continuidad en las series temporales sin necesidad de eliminar datos. Además, verificaste correctamente que no quedaron NaNs en los conjuntos. 🧼✅
#
# </div>

# %% [markdown]
# #### 1.4.3 Eliminar columnas que no están en df_test de df_train

# %%
# Obtenemos las columnas del df_test
test_cols = set(df_test.columns)

# Las columnas objetivo siempre deben ser parte del df_train (para entrenamiento)
# y las necesitamos para comparar con las predicciones del modelo en df_test después.
# Vamos a extraer los objetivos de df_full ya que df_test no los tiene.
# Primero, asegurémonos de que df_full también tiene su índice 'date' y está ordenado.
df_full.sort_index(inplace=True)

# Unimos las columnas objetivo de df_full a df_test basándose en el índice de fecha
# Esto es crucial para poder calcular el sMAPE en el conjunto de prueba al final.
# Unimos por índice 'date' asegura que los objetivos se asignen a las filas correctas.
df_test = df_test.merge(df_full[['rougher.output.recovery', 'final.output.recovery']], 
                        left_index=True, right_index=True, how='left')

# Ahora, eliminamos las columnas de df_train que no están en el df_test (excluyendo los objetivos que acabamos de 
# añadir a df_test para alineación de evaluaciones)
# Las columnas objetivo que necesitamos para el entrenamiento son 'rougher.output.recovery' y 'final.output.recovery'.
# Estas son las que usaremos para entrenar en df_train, pero solo las predicciones se harán sobre df_test.
# Por lo tanto, no se deben eliminar de df_train.
# Para las características predictoras, SÓLO usaremos las que están en df_test.

# Identificamos las características (features) que debemos mantener en df_train
# Estas son las columnas que están en df_test (excepto 'date', que ya es el índice)
features_to_keep_in_train = list(test_cols)

# Añadimos las columnas objetivo a la lista de columnas a mantener en df_train
# Esto es esencial porque df_train es nuestro conjunto de entrenamiento completo con targets
features_to_keep_in_train.append('rougher.output.recovery')
features_to_keep_in_train.append('final.output.recovery')

# Eliminamos cualquier duplicado y nos aseguramos de que sean columnas existentes en df_train
features_to_keep_in_train = list(set(features_to_keep_in_train).intersection(df_train.columns))

# Filtramos df_train para que solo contenga estas características y los objetivos
df_train = df_train[features_to_keep_in_train]

print(f"\nNúmero de columnas en df_train después de la limpieza: {df_train.shape[1]}")
print(f"Número de columnas en df_test después de añadir objetivos: {df_test.shape[1]}")

# Verificamos si aún hay NaNs después del ffill/bfill (debería ser muy pocos o ninguno)
print("\nConteo de NaNs después del preprocesamiento en df_train:")
print(df_train.isnull().sum().sum()) # Suma total de NaNs en df_train

print("\nConteo de NaNs después del preprocesamiento en df_test:")
print(df_test.isnull().sum().sum()) # Suma total de NaNs en df_test
# Out:
# Número de columnas en df_train después de la limpieza: 54
# Número de columnas en df_test después de añadir objetivos: 54
#
# Conteo de NaNs después del preprocesamiento en df_train:
# 0
#
# Conteo de NaNs después del preprocesamiento en df_test:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente procedimiento al identificar y eliminar columnas que representan "fugas de datos" (data leakage) del conjunto de entrenamiento. La lógica para conservar solo variables presentes en ambos conjuntos y los objetivos es sólida. Además, añadiste correctamente las columnas target a df_test desde df_full. 🔍💡
#
# </div>

# %% [markdown]
# # 2.-Analiza los datos

# %% [markdown]
# ### 2.1. Observa cómo cambia la concentración de metales (Au, Ag, Pb) en función de la etapa de purificación.

# %%
# Utilizaremos el DataFrame df_full para este análisis, ya que contiene todas las etapas y sus concentraciones.
# Definimos las columnas de concentración para cada metal en cada etapa
metals = ['au', 'ag', 'pb']
stages = {
    'Materia Prima': 'rougher.input.feed_',
    'Concentrado Rougher': 'rougher.output.concentrate_',
    'Limpieza Primaria': 'primary_cleaner.output.concentrate_',
    'Concentrado Final': 'final.output.concentrate_'
}

# Creamos un DataFrame para almacenar las concentraciones promedio
concentration_data = pd.DataFrame(columns=['Etapa', 'Metal', 'Concentración Promedio'])

for metal in metals:
    for stage_name, col_prefix in stages.items():
        col_name = col_prefix + metal
        if col_name in df_full.columns: # Asegurarse de que la columna exista
            avg_concentration = df_full[col_name].mean()
            concentration_data = pd.concat([concentration_data, pd.DataFrame([{'Etapa': stage_name, 'Metal': metal, 'Concentración Promedio': avg_concentration}])], ignore_index=True)

# Visualiza los resultados
plt.figure(figsize=(12, 7))
sns.barplot(x='Etapa', y='Concentración Promedio', hue='Metal', data=concentration_data, palette='viridis')
plt.title('Cambio en la concentración promedio de metales por etapa de purificación')
plt.xlabel('Etapa de Purificación')
plt.ylabel('Concentración Promedio')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Metal')
plt.show()

print("\nConcentraciones promedio de metales por etapa de purificación:")
print(concentration_data)
# Out:
# Concentraciones promedio de metales por etapa de purificación:
#                   Etapa Metal  Concentración Promedio
# 0         Materia Prima    au                7.545861
# 1   Concentrado Rougher    au               17.831509
# 2     Limpieza Primaria    au               29.119967
# 3     Concentrado Final    au               39.891718
# 4         Materia Prima    ag                8.044237
# 5   Concentrado Rougher    ag               10.845609
# 6     Limpieza Primaria    ag                7.666972
# 7     Concentrado Final    ag                4.768013
# 8         Materia Prima    pb                3.282945
# 9   Concentrado Rougher    pb                6.886869
# 10    Limpieza Primaria    pb                8.809217
# 11    Concentrado Final    pb                9.071366

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Buen enfoque para comparar cómo varía la concentración de metales (Au, Ag, Pb) a lo largo de las etapas del proceso. El uso de un DataFrame resumen para visualizar las medias y luego graficar con seaborn es una práctica excelente. 👏📊
#
# </div>

# %% [markdown]
# ### 2.2. Compara las distribuciones del tamaño de las partículas de la alimentación en el conjunto de entrenamiento y en el conjunto de prueba.

# %%
# Selecciona la columna relevante
feature = 'rougher.input.feed_size'

# Creamos el gráfico de densidad (KDE plot)
plt.figure(figsize=(10, 6))
sns.kdeplot(df_train[feature], label='Conjunto de Entrenamiento', fill=True, alpha=0.5)
sns.kdeplot(df_test[feature], label='Conjunto de Prueba', fill=True, alpha=0.5)
plt.title(f'Distribución del tamaño de las partículas de la alimentación ({feature})')
plt.xlabel('Tamaño de las Partículas')
plt.ylabel('Densidad')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# También podemos imprimir algunas estadísticas descriptivas para una comparación numérica
print(f"\nEstadísticas descriptivas para '{feature}' en el conjunto de entrenamiento:")
print(df_train[feature].describe())

print(f"\nEstadísticas descriptivas para '{feature}' en el conjunto de prueba:")
print(df_test[feature].describe())
# Out:
# Estadísticas descriptivas para 'rougher.input.feed_size' en el conjunto de entrenamiento:
# count    16860.000000
# mean        60.188595
# std         30.522242
# min          9.659576
# 25%         47.548897
# 50%         54.066003
# 75%         65.397249
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64
#
# Estadísticas descriptivas para 'rougher.input.feed_size' en el conjunto de prueba:
# count    5856.000000
# mean       55.898866
# std        22.707969
# min         0.046369
# 25%        43.852884
# 50%        49.964796
# 75%        61.628003
# max       477.445473
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# Si bien las distribuciones no son idénticas, y la del conjunto de prueba parece ligeramente sesgada hacia tamaños de partícula más pequeños y con menor variabilidad, no parece haber una variación tan significativa que invalide completamente la evaluación del modelo. Las diferencias en la media y la desviación estándar son lo suficientemente pequeñas como para no preocuparnos demasiado.

# %% [markdown]
# <div class="alert alert-block alert-warning"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Atención</b> ⚠️ - Correcto uso de gráficos de densidad y estadísticas descriptivas para comparar los conjuntos de entrenamiento y prueba. Como mejora, podrías agregar una prueba estadística (por ejemplo, Kolmogorov-Smirnov o Mann-Whitney U) para cuantificar la diferencia entre distribuciones. ¡Vas muy bien!
#
# </div>

# %% [markdown]
# ### 2.3. Considera las concentraciones totales de todas las sustancias en las diferentes etapas: materia prima, concentrado rougher y concentrado final.

# %%
# Definimos las columnas para cada etapa y metal/sustancia
stages_concentrations = {
    'Materia Prima (Alimentación)': ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol'],
    'Concentrado Rougher': ['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol'],
    'Concentrado Final': ['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']
}

# Calcula la concentración total para cada etapa
for stage_name, cols in stages_concentrations.items():
    # las columnas existan antes de sumarlas?
    existing_cols = [col for col in cols if col in df_full.columns]
    df_full[f'total_concentration_{stage_name.replace(" ", "_").lower()}'] = df_full[existing_cols].sum(axis=1)
    print(f"Calculada la concentración total para: {stage_name}")

# Visualizamos las distribuciones de las concentraciones totales
plt.figure(figsize=(15, 6))

for i, (stage_name, _) in enumerate(stages_concentrations.items()):
    col_name = f'total_concentration_{stage_name.replace(" ", "_").lower()}'
    plt.subplot(1, len(stages_concentrations), i + 1)
    sns.histplot(df_full[col_name], kde=True, bins=50)
    plt.title(f'Distribución de Concentración Total en {stage_name}')
    plt.xlabel('Concentración Total')
    plt.ylabel('Frecuencia')
    plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# Analiza valores anormales (cercanos a cero)
print("\n--- Análisis de valores anormales (concentración total cercana a cero) ---")
for stage_name, _ in stages_concentrations.items():
    col_name = f'total_concentration_{stage_name.replace(" ", "_").lower()}'
    # Contar cuántas filas tienen una concentración total muy baja (cercana a cero)
    # Por ejemplo, < 1.0 o incluso menos si la distribución muestra un pico en 0.
    # Usaremos un umbral de 0.1 para identificar valores "casi cero"
    abnormal_count = df_full[df_full[col_name] < 0.1].shape[0]
    total_count = df_full.shape[0]
    print(f"Etapa '{stage_name}': {abnormal_count} filas con concentración total < 0.1 (de {total_count} total).")

    # Si hay valores anormales, vemos sus estadísticas o algunos ejemplos
    if abnormal_count > 0:
        print(f"Estadísticas para valores anormales en '{stage_name}':")
        print(df_full[df_full[col_name] < 0.1][col_name].describe())
# Out:
# Calculada la concentración total para: Materia Prima (Alimentación)
# Calculada la concentración total para: Concentrado Rougher
# Calculada la concentración total para: Concentrado Final
# --- Análisis de valores anormales (concentración total cercana a cero) ---
# Etapa 'Materia Prima (Alimentación)': 1957 filas con concentración total < 0.1 (de 22716 total).
# Estadísticas para valores anormales en 'Materia Prima (Alimentación)':
# count    1957.000000
# mean        0.007624
# std         0.015715
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.040000
# Name: total_concentration_materia_prima_(alimentación), dtype: float64
# Etapa 'Concentrado Rougher': 2458 filas con concentración total < 0.1 (de 22716 total).
# Estadísticas para valores anormales en 'Concentrado Rougher':
# count    2458.000000
# mean        0.007309
# std         0.015465
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# ...

# %% [markdown]
# Podemos ver unos picos anormales al inicio de cada grafica por lo que los eliminaremos para evitar errores en la prediccion,
# utilizamos df_full para identificar los índices a eliminar para asegurar la consistencia, y luego aplicamos esa eliminación a df_train y df_test individualmente.

# %%
# Calculamos las concentraciones totales en df_full para identificar las filas a eliminar
# Usamos df_full para identificar los índices a eliminar y luego aplicamos a df_train y df_test

# Definimos las columnas para cada etapa y metal/sustancia para calcular la concentración total
stages_concentrations_cols = {
    'rougher.input': ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol'],
    'rougher.output': ['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol'],
    'final.output': ['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']
}

# Identificamos las filas con concentración total anormalmente baja en df_full
rows_to_drop_indices = pd.Index([]) # Inicializa un índice vacío para acumular

for stage_prefix, cols in stages_concentrations_cols.items():
    # Aseguramos de que todas las columnas existan antes de sumarlas
    existing_cols = [col for col in cols if col in df_full.columns]
    if existing_cols: # Solo si hay columnas existentes para sumar
        total_concentration = df_full[existing_cols].sum(axis=1)
        # Identificamos índices donde la concentración total es muy baja
        # Umbral: Por ejemplo, menos de 1.0. Puedes ajustarlo si crees que 0.1 es mejor.
        abnormal_indices = total_concentration[total_concentration < 1.0].index
        rows_to_drop_indices = rows_to_drop_indices.union(abnormal_indices) # Unir los índices anormales

print(f"Número de filas con concentración total anormalmente baja identificadas en df_full: {len(rows_to_drop_indices)}")

# Eliminamos las filas identificadas de df_train y df_test
# Usamos .drop(index=...) para eliminar las filas por su índice de fecha
initial_train_rows = df_train.shape[0]
initial_test_rows = df_test.shape[0]

df_train_cleaned = df_train.drop(index=rows_to_drop_indices, errors='ignore') # 'errors=ignore' evita errores si un índice no existe
df_test_cleaned = df_test.drop(index=rows_to_drop_indices, errors='ignore')

print(f"Filas eliminadas de df_train: {initial_train_rows - df_train_cleaned.shape[0]}")
print(f"Filas eliminadas de df_test: {initial_test_rows - df_test_cleaned.shape[0]}")

# Actualizamos los DataFrames originales con las versiones limpias
df_train = df_train_cleaned
df_test = df_test_cleaned

print(f"\nDimensiones de df_train después de eliminar anomalías: {df_train.shape}")
print(f"Dimensiones de df_test después de eliminar anomalías: {df_test.shape}")

# Verificación final de NaNs (deberían ser cero)
print("\nVerificación final de NaNs en df_train (después de limpieza y eliminación de anomalías):", df_train.isnull().sum().sum())
print("Verificación final de NaNs en df_test (después de limpieza y eliminación de anomalías):", df_test.isnull().sum().sum())
# Out:
# Número de filas con concentración total anormalmente baja identificadas en df_full: 2814
# Filas eliminadas de df_train: 2248
# Filas eliminadas de df_test: 566
#
# Dimensiones de df_train después de eliminar anomalías: (14612, 54)
# Dimensiones de df_test después de eliminar anomalías: (5290, 54)
#
# Verificación final de NaNs en df_train (después de limpieza y eliminación de anomalías): 0
# Verificación final de NaNs en df_test (después de limpieza y eliminación de anomalías): 0

# %%
# Hacemos la comprovacion 
# Definimos las columnas para cada etapa y metal/sustancia para calcular la concentración total
# Aseguramos de que estas columnas existan en df_train y df_test (que es el propósito de la limpieza anterior)
stages_concentrations_cols_train = {
    'Materia Prima (Alimentación)': ['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol'],
    'Concentrado Rougher': ['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol'],
    'Concentrado Final': ['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']
}

# Calculamos la concentración total para cada etapa en df_train (el conjunto principal para modelado)
for stage_name, cols in stages_concentrations_cols_train.items():
    existing_cols = [col for col in cols if col in df_train.columns] # Asegurarse que las columnas existan en el df_train limpiado
    if existing_cols:
        df_train[f'total_concentration_{stage_name.replace(" ", "_").lower()}'] = df_train[existing_cols].sum(axis=1)

# Visualizamos las distribuciones de las concentraciones totales en df_train (después de la limpieza)
plt.figure(figsize=(15, 6))

for i, (stage_name, _) in enumerate(stages_concentrations_cols_train.items()):
    col_name = f'total_concentration_{stage_name.replace(" ", "_").lower()}'
    if col_name in df_train.columns: # Verificar que la columna de concentración total existe en df_train
        plt.subplot(1, len(stages_concentrations_cols_train), i + 1)
        sns.histplot(df_train[col_name], kde=True, bins=50)
        plt.title(f'Distribución de Concentración Total en {stage_name} (df_train, Limpio)')
        plt.xlabel('Concentración Total')
        plt.ylabel('Frecuencia')
        plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

print("Los gráficos de distribución de concentración total para df_train (limpio) han sido generados. Por favor, revisa si los picos cercanos a cero han desaparecido.")
# Out:
# Los gráficos de distribución de concentración total para df_train (limpio) han sido generados. Por favor, revisa si los picos cercanos a cero han desaparecido.

# %% [markdown]
# # 3. Contruye el modelo

# %% [markdown]
# ### 3.1. Escribe una función para calcular el valor final de sMAPE.

# %%
# Definir las funciones smape y final_smape 
def smape(y_true, y_pred):
    numerator = np.abs(y_true - y_pred)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    smape_value_per_sample = np.where(denominator == 0, 0, numerator / denominator)
    return np.mean(smape_value_per_sample) * 100

def final_smape(smape_rougher, smape_final):
    return 0.25 * smape_rougher + 0.75 * smape_final

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Has definido correctamente la métrica sMAPE, una elección adecuada para problemas donde los errores relativos son importantes. También es muy positivo que encapsulaste el cálculo ponderado en final_smape, lo cual te ayuda a mantener el código limpio y reutilizable. ✅
#
# </div>

# %% [markdown]
# ### 3.2. Entrena diferentes modelos

# %% [markdown]
# #### 3.2.1: Preparación de X e Y

# %%
# Obtenemos las columnas de características a usar (las que están en df_test como features)
target_cols = ['rougher.output.recovery', 'final.output.recovery']
features_cols = [col for col in df_test.columns if col not in target_cols]

# Asegurar que df_train solo contenga las características y objetivos relevantes
# Esto es vital para que las columnas de X_train y X_test coincidan.
required_cols_in_train = features_cols + target_cols
df_train = df_train[[col for col in required_cols_in_train if col in df_train.columns]]

# Dividimos los datos de entrenamiento en características y objetivos
X_train = df_train[features_cols]
y_train_rougher = df_train['rougher.output.recovery']
y_train_final = df_train['final.output.recovery']

# Preparar X_test (solo características)
X_test = df_test[features_cols]

# %% [markdown]
# #### 3.2.2 Configuración de Scorer y Modelos, Entrenamiento y Evaluación CV

# %%
# Definimos los scorers sMAPE personalizados
smape_scorer_rougher = make_scorer(smape, greater_is_better=False)
smape_scorer_final = make_scorer(smape, greater_is_better=False)

# Modelos y sus parámetros para GridSearchCV
models = {
    'LinearRegression': {
        'model': LinearRegression(),
        'params': {}
    },
    'DecisionTreeRegressor': {
        'model': DecisionTreeRegressor(random_state=123),
        'params': {
            'max_depth': [5, 10, 15]
        }
    },
    'RandomForestRegressor': {
        'model': RandomForestRegressor(random_state=123),
        'params': {
            'n_estimators': [10, 30, 50],
            'max_depth': [5, 10]
        }
    }
}

best_models = {}
best_scores = {}

# Entrenamiento y evaluación para la Recuperación Rougher
print("--- Entrenando y evaluando modelos para rougher.output.recovery ---")
for model_name, config in models.items():
    print(f"\nProcesando {model_name} para Rougher Recovery...")
    grid_search = GridSearchCV(
        estimator=config['model'],
        param_grid=config['params'],
        scoring=smape_scorer_rougher,
        cv=5,
        n_jobs=-1,
        verbose=1
    )
    grid_search.fit(X_train, y_train_rougher)

    best_models[f'rougher_{model_name}'] = grid_search.best_estimator_
    best_scores[f'rougher_{model_name}_smape'] = -grid_search.best_score_
    print(f"Mejores parámetros para {model_name} (Rougher): {grid_search.best_params_}")
    print(f"Mejor sMAPE CV para {model_name} (Rougher): {best_scores[f'rougher_{model_name}_smape']:.4f}")

# Entrenamiento y evaluación para la Recuperación Final
print("\n--- Entrenando y evaluando modelos para final.output.recovery ---")
for model_name, config in models.items():
    print(f"\nProcesando {model_name} para Final Recovery...")
    grid_search = GridSearchCV(
        estimator=config['model'],
        param_grid=config['params'],
        scoring=smape_scorer_final,
        cv=5,
        n_jobs=-1,
        verbose=1
    )
    grid_search.fit(X_train, y_train_final)

    best_models[f'final_{model_name}'] = grid_search.best_estimator_
    best_scores[f'final_{model_name}_smape'] = -grid_search.best_score_
    print(f"Mejores parámetros para {model_name} (Final): {grid_search.best_params_}")
    print(f"Mejor sMAPE CV para {model_name} (Final): {best_scores[f'final_{model_name}_smape']:.4f}")

print("\n--- Resumen de los mejores sMAPE CV por modelo y etapa ---")
for key, value in best_scores.items():
    print(f"{key}: {value:.4f}")

# Selección del Mejor Modelo Combinado
print("\n--- Calculando sMAPE final ponderado para las mejores combinaciones ---")
combined_smape_scores = {}

for model_name in models.keys():
    smape_rougher = best_scores[f'rougher_{model_name}_smape']
    smape_final = best_scores[f'final_{model_name}_smape']
    combined_smape = final_smape(smape_rougher, smape_final)
    combined_smape_scores[model_name] = combined_smape
    print(f"sMAPE Final Ponderado para {model_name}: {combined_smape:.4f}")

# Encontrar el mejor modelo general
best_overall_model_name = min(combined_smape_scores, key=combined_smape_scores.get)
print(f"\nEl mejor modelo general (con el sMAPE final ponderado más bajo) es: {best_overall_model_name}")

# Almacenar los modelos seleccionados para la prueba final
best_rougher_model = best_models[f'rougher_{best_overall_model_name}']
best_final_model = best_models[f'final_{best_overall_model_name}']

print(f"\nLos modelos seleccionados para la prueba final son:")
print(f"  - Rougher: {best_rougher_model.__class__.__name__} con parámetros {best_rougher_model.get_params()}")
print(f"  - Final: {best_final_model.__class__.__name__} con parámetros {best_final_model.get_params()}")
# Out:
# --- Entrenando y evaluando modelos para rougher.output.recovery ---
#
# Procesando LinearRegression para Rougher Recovery...
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Mejores parámetros para LinearRegression (Rougher): {}
# Mejor sMAPE CV para LinearRegression (Rougher): 8.5905
#
# Procesando DecisionTreeRegressor para Rougher Recovery...
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# Mejores parámetros para DecisionTreeRegressor (Rougher): {'max_depth': 5}
# Mejor sMAPE CV para DecisionTreeRegressor (Rougher): 11.5376
#
# Procesando RandomForestRegressor para Rougher Recovery...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Mejores parámetros para RandomForestRegressor (Rougher): {'max_depth': 5, 'n_estimators': 50}
# Mejor sMAPE CV para RandomForestRegressor (Rougher): 8.1995
#
# --- Entrenando y evaluando modelos para final.output.recovery ---
#
# Procesando LinearRegression para Final Recovery...
# ...

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - Excelente enfoque al preparar los datos, definir make_scorer personalizado, y usar GridSearchCV con cv=5 para cada modelo y objetivo. Además, evaluaste todos los modelos de forma consistente y seleccionaste el mejor basándote en un criterio bien definido (sMAPE final ponderado). ¡Una implementación de pipeline muy profesional!
#
# </div>

# %% [markdown]
# ### 3.3. Prueba el mejor modelo utilizando la muestra de prueba.

# %%
# Re-entrenar los modelos seleccionados con el conjunto de entrenamiento completo
# (Esto ya lo hace GridSearchCV internamente al obtener .best_estimator_, pero lo explicitamos aquí)
best_rougher_model.fit(X_train, y_train_rougher)
best_final_model.fit(X_train, y_train_final)

# Realizar predicciones en el conjunto de prueba
predictions_rougher = best_rougher_model.predict(X_test)
predictions_final = best_final_model.predict(X_test)

# Obtenemos los valores reales de recuperación del conjunto de prueba
y_test_rougher = df_test['rougher.output.recovery']
y_test_final = df_test['final.output.recovery']

# Calculamos sMAPE para cada etapa en el conjunto de prueba
smape_rougher_test = smape(y_test_rougher, predictions_rougher)
smape_final_test = smape(y_test_final, predictions_final)

print(f"\nsMAPE para rougher.output.recovery en la muestra de prueba: {smape_rougher_test:.4f}")
print(f"sMAPE para final.output.recovery en la muestra de prueba: {smape_final_test:.4f}")

# Calculamos el sMAPE final ponderado
final_smape_test = final_smape(smape_rougher_test, smape_final_test)

print(f"\n--- sMAPE FINAL PONDERADO en la MUESTRA DE PRUEBA: {final_smape_test:.4f} ---")
# Out:
# sMAPE para rougher.output.recovery en la muestra de prueba: 6.3316
# sMAPE para final.output.recovery en la muestra de prueba: 9.1159
#
# --- sMAPE FINAL PONDERADO en la MUESTRA DE PRUEBA: 8.4198 ---

# %% [markdown]
# El RandomForestRegressor fue seleccionado como el mejor modelo, mostrando consistentemente los mejores resultados de sMAPE en ambas etapas (rougher y final) y el mejor sMAPE final ponderado en CV (9.2259).
#
# Finalmente, probamos el modelo seleccionado en el conjunto de prueba, obteniendo un sMAPE final ponderado de 8.4198, lo que demuestra la buena capacidad de generalización del modelo.

# %% [markdown]
# <div class="alert alert-block alert-success"> <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
# <b>Éxito</b> - El procedimiento de prueba fue claro y correcto: reentrenaste con los datos completos, generaste predicciones y evaluaste el rendimiento en el conjunto de prueba. El modelo RandomForest obtuvo un rendimiento notable (sMAPE final ≈ 8.42), lo que confirma su buena capacidad de generalización. Muy bien documentado todo el proceso. 👏🎯
#
# </div>

# %% [markdown]
# # Comentario General del Revisor
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a>
#
# ¡Felicidades! Tu proyecto está <b>aprobado</b>. Mostraste un dominio excelente del flujo completo de trabajo en ciencia de datos: desde la limpieza y exploración, hasta la construcción y evaluación de modelos con métricas personalizadas. El análisis está bien estructurado y justificado con decisiones técnicas sólidas.
#
# #### Puntos Positivos:
#
# * **Preprocesamiento detallado:** Identificaste correctamente variables con fugas de datos y trabajaste meticulosamente en la imputación de valores nulos.
# * **Validación de fórmula:** Excelente validación matemática del campo `recovery`, con uso de MAE para confirmar consistencia.
# * **Modelado robusto:** Evaluaste múltiples modelos (Lineal, Árbol, Bosques Aleatorios), usaste `GridSearchCV` y definiste una métrica personalizada (sMAPE) que refleja bien el objetivo del negocio.
# * **Evaluación y selección clara:** Definiste una función combinada (`final_smape`) para comparar modelos y justificaste la elección final con evidencia.
#
# #### Áreas para Seguir Investigando:
#
# * **Optimización del preprocesamiento:** Podrías explorar imputaciones con modelos más inteligentes (ej. KNNImputer) en lugar de solo `ffill` y `bfill`.
# * **Modelos avanzados:** Considera incorporar modelos como Gradient Boosting (XGBoost, LightGBM) para explorar posibles mejoras de rendimiento.
# * **Interpretabilidad del modelo:** Añadir análisis de importancia de características (feature importance) para entender qué variables influyen más.
# * **Automatización del pipeline:** Podrías encapsular el proceso completo de entrenamiento y validación en funciones o pipelines de `sklearn`.
#
# ¡Gran trabajo! Tu proyecto es un excelente ejemplo de cómo aplicar técnicas de ciencia de datos para resolver problemas del mundo real. 🚀📈🔬
#
# </div>
